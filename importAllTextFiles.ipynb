# %%
import pandas as pd
#read and convert one txt file into a df
df = pd.read_csv('AK.txt', delimiter=",", header=None,names=['State', 'Sex', 'year', 'Name', 'Number'])
df.head()
# Out:
#   State Sex  year      Name  Number
# 0    AK   F  1910      Mary      14
# 1    AK   F  1910     Annie      12
# 2    AK   F  1910      Anna      10
# 3    AK   F  1910  Margaret       8
# 4    AK   F  1910     Helen       7

# %%
import pandas as pd
from glob import glob as gg

name_df = pd.DataFrame()
column_names = ['state', 'gender', 'year', 'name', 'count']

for f in gg('data/*.txt'):
    tmp = pd.read_csv(f,names=column_names)

    name_df = pd.concat([data,tmp],axis=0,ignore_index=True)
name_df
# Out:
#         state gender  year         name  count
# 0          AK      F  1910         Mary     14
# 1          AK      F  1910        Annie     12
# 2          AK      F  1910         Anna     10
# 3          AK      F  1910     Margaret      8
# 4          AK      F  1910        Helen      7
# 5          AK      F  1910        Elsie      6
# 6          AK      F  1910         Lucy      6
# 7          AK      F  1910      Dorothy      5
# 8          AK      F  1911         Mary     12
# 9          AK      F  1911     Margaret      7
# 10         AK      F  1911         Ruth      7
# 11         AK      F  1911        Annie      6
# 12         AK      F  1911    Elizabeth      6
# 13         AK      F  1911        Helen      6
# 14         AK      F  1912         Mary      9
# 15         AK      F  1912        Elsie      8
# 16         AK      F  1912        Agnes      7
# 17         AK      F  1912         Anna      7
# 18         AK      F  1912        Helen      7
# ...
