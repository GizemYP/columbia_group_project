# %%
import pandas as pd
import glob

#create a dataframe
name_df = pd.DataFrame()

#open, read all text files and name the column labels
for files in glob.glob('SSN_data/*.txt'):
    comb_data = pd.read_csv(files,names=['state', 'gender', 'year', 'name', 'count'])
#concatenate text files in the dataframe
    name_df = pd.concat([name_df,comb_data],axis=0,ignore_index=True)
name_df.head()
# Out:
#   state gender  year      name  count
# 0    AK      F  1910      Mary     14
# 1    AK      F  1910     Annie     12
# 2    AK      F  1910      Anna     10
# 3    AK      F  1910  Margaret      8
# 4    AK      F  1910     Helen      7

# %%
# bins

bins = [1909, 1919, 1929, 1939, 1949, 1959, 1969, 1979, 1989, 1999, 2009, 2018]
group_names = ["10s", "20s", "30s", "40s", "50s", "60s", "70s", "80s", "90s", "00s", "2010s"]

# %%
name_df["decades"] = pd.cut(name_df["year"], bins, labels=group_names)
name_df.head()
# Out:
#   state gender  year      name  count decades
# 0    AK      F  1910      Mary     14     10s
# 1    AK      F  1910     Annie     12     10s
# 2    AK      F  1910      Anna     10     10s
# 3    AK      F  1910  Margaret      8     10s
# 4    AK      F  1910     Helen      7     10s

# %%
cut_df = name_df.drop(('year'),axis=1)
cut_df.head(30)
# Out:
#    state gender       name  count decades
# 0     AK      F       Mary     14     10s
# 1     AK      F      Annie     12     10s
# 2     AK      F       Anna     10     10s
# 3     AK      F   Margaret      8     10s
# 4     AK      F      Helen      7     10s
# 5     AK      F      Elsie      6     10s
# 6     AK      F       Lucy      6     10s
# 7     AK      F    Dorothy      5     10s
# 8     AK      F       Mary     12     10s
# 9     AK      F   Margaret      7     10s
# 10    AK      F       Ruth      7     10s
# 11    AK      F      Annie      6     10s
# 12    AK      F  Elizabeth      6     10s
# 13    AK      F      Helen      6     10s
# 14    AK      F       Mary      9     10s
# 15    AK      F      Elsie      8     10s
# 16    AK      F      Agnes      7     10s
# 17    AK      F       Anna      7     10s
# 18    AK      F      Helen      7     10s
# 19    AK      F     Louise      7     10s
# 20    AK      F       Jean      6     10s
# 21    AK      F       Ruth      6     10s
# 22    AK      F      Alice      5     10s
# 23    AK      F     Esther      5     10s
# 24    AK      F      Ethel      5     10s
# 25    AK      F   Margaret      5     10s
# 26    AK      F      Marie      5     10s
# 27    AK      F       Mary     21     10s
# 28    AK      F  Elizabeth      9     10s
# 29    AK      F   Margaret      8     10s

# %%
# check if there's many rows
cut_df.loc[(cut_df['state']== 'AK') & (cut_df['name'] == 'Mary')].head(20)
# Out:
#     state gender  name  count decades
# 0      AK      F  Mary     14     10s
# 8      AK      F  Mary     12     10s
# 14     AK      F  Mary      9     10s
# 27     AK      F  Mary     21     10s
# 34     AK      F  Mary     22     10s
# 50     AK      F  Mary     23     10s
# 69     AK      F  Mary     18     10s
# 91     AK      F  Mary     21     10s
# 106    AK      F  Mary     27     10s
# 125    AK      F  Mary     22     10s
# 152    AK      F  Mary     38     20s
# 177    AK      F  Mary     36     20s
# 199    AK      F  Mary     29     20s
# 219    AK      F  Mary     26     20s
# 244    AK      F  Mary     41     20s
# 264    AK      F  Mary     24     20s
# 292    AK      F  Mary     39     20s
# 317    AK      F  Mary     30     20s
# 343    AK      F  Mary     27     20s
# 370    AK      F  Mary     25     20s

# %%
df.groupby('id')['value'].nlargest(2).sum(level=0).nlargest(2)

# %%
grouped_df = cut_df.groupby(["decades", "state", "gender", "name"])['count'].nlargest(2).sum(level=0).nlargest(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in curried_with_axis(x)
#     590             def curried_with_axis(x):
# --> 591                 return f(x, *args, **kwargs_with_axis)
#     592
#
# TypeError: nlargest() got an unexpected keyword argument 'axis'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in wrapper(*args, **kwargs)
#     605             try:
# --> 606                 return self.apply(curried_with_axis)
#     607             except Exception:
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     700                 with _group_selection_context(self):
# --> 701                     return self._python_apply_general(f)
#     702
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in curried_with_axis(x)
#     590             def curried_with_axis(x):
# --> 591                 return f(x, *args, **kwargs_with_axis)
#     592
#
# TypeError: nlargest() got an unexpected keyword argument 'axis'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-6958f602a4ab> in <module>
# ----> 1 grouped_df = cut_df.groupby(["decades", "state", "gender", "name"])['count'].nlargest(2).sum(level=0).nlargest(2)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in wrapper(*args, **kwargs)
#     607             except Exception:
#     608                 try:
# --> 609                     return self.apply(curried)
#     610                 except Exception:
#     611
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     747                       examples=_apply_docs['series_examples']))
#     748     def apply(self, func, *args, **kwargs):
# --> 749         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#     750
#     751     @Substitution(see_also=_agg_see_also_doc,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in curried(x)
#     592
#     593             def curried(x):
# --> 594                 return f(x, *args, **kwargs)
#     595
#     596             # preserve the name so we can detect it when calling plot methods,
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in nlargest(self, n, keep)
#    3118         dtype: int64
#    3119         """
# -> 3120         return algorithms.SelectNSeries(self, n=n, keep=keep).nlargest()
#    3121
#    3122     def nsmallest(self, n=5, keep='first'):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in nlargest(self)
#    1056
#    1057     def nlargest(self):
# -> 1058         return self.compute('nlargest')
#    1059
#    1060     def nsmallest(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\algorithms.py in compute(self, method)
#    1098             return self.obj[[]]
#    1099
# -> 1100         dropped = self.obj.dropna()
#    1101
#    1102         # slow method
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in dropna(self, axis, inplace, **kwargs)
#    4309                 pass
#    4310             else:
# -> 4311                 return self.copy()
#    4312
#    4313     def valid(self, inplace=False, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5802         dtype: object
#    5803         """
# -> 5804         data = self._data.copy(deep=deep)
#    5805         return self._constructor(data).__finalize__(self)
#    5806
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     732             new_axes = list(self.axes)
#     733         return self.apply('copy', axes=new_axes, deep=deep,
# --> 734                           do_integrity_check=False)
#     735
#     736     def as_array(self, transpose=False, items=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     751         values = self.values
#     752         if deep:
# --> 753             values = values.copy()
#     754         return self.make_block_same_class(values)
#     755
#
# KeyboardInterrupt:

# %%
sum_df = grouped_df["count"].sum()
sum_df
# Out:
# decades  state  gender  name
# 10s      AK     F       Agnes         24
#                         Alice         51
#                         Ann            5
#                         Anna          52
#                         Annie         53
#                         Barbara        6
#                         Betty         11
#                         Clara         22
#                         Daisy          5
#                         Dorothy       48
#                         Edith          5
#                         Edna           5
#                         Elizabeth     42
#                         Elsie         19
#                         Emma          17
#                         Esther        15
#                         Ethel          5
#                         Evelyn        10
#                         Florence      10
#                         Frances       34
#                         Gertrude       8
#                         Gladys         6
#                         Hazel          5
#                         Helen         89
#                         Irene          8
#                         Jean          12
#                         Josephine      5
#                         Julia         23
#                         Katherine     16
#                         Kathryn        5
#                                     ...
# 2010s    WY     M       Thomas       105
#                         Timothy       35
#                         Titus         16
#                         Trace          5
#                         Travis        14
#                         Trenton       29
#                         Trevor        16
#                         Tristan       58
#                         Troy           5
#                         Tucker        87
#                         Ty            24
#                         Tyce           5
#                         Tyler         74
#                         Tyson         30
#                         Victor        13
#                         Vincent       41
#                         Walker         6
#                         Walter         7
#                         Waylon        28
#                         Wesley        50
#                         Weston       114
#                         William      247
#                         Wyatt        280
#                         Xander        39
#                         Xavier        58
#                         Zachary       42
#                         Zander        29
#                         Zane          29
#                         Zayden        35
#                         Zayne          5
# Name: count, Length: 1069222, dtype: int64

# %%
#sum_df.loc[["10s", "20s", "30s", "40s", "50s", "60s", "70s", "80s", "90", "00s" "2010s"],"AK"].nlargest(120)

# %%
final_df = pd.DataFrame(sum_df).sort_values(by=["decades", 'state','gender','count'], ascending=[True, True,True, False])
final_df
# Out:
#                                 count
# decades state gender name
# 10s     AK    F      Mary         189
#                      Margaret      92
#                      Helen         89
#                      Annie         53
#                      Anna          52
#                      Ruth          52
#                      Alice         51
#                      Dorothy       48
#                      Elizabeth     42
#                      Frances       34
#                      Marie         32
#                      Martha        31
#                      Agnes         24
#                      Julia         23
#                      Louise        23
#                      Clara         22
#                      Elsie         19
#                      Emma          17
#                      Katherine     16
#                      Virginia      16
#                      Esther        15
#                      Jean          12
#                      Betty         11
#                      Lillian       11
#                      Lucy          11
#                      Evelyn        10
#                      Florence      10
#                      Minnie        10
#                      Pauline       10
#                      Vera          10
# ...                               ...
# 2010s   WY    M      Ellis          5
#                      Emerson        5
#                      Emilio         5
#                      Finley         5
#                      Ivan           5
#                      Javier         5
#                      Jeffrey        5
#                      Judah          5
#                      Julius         5
#                      Kaison         5
#                      Kason          5
#                      Kellan         5
#                      Kellen         5
#                      Kyson          5
#                      Manuel         5
#                      Matthias       5
#                      Morgan         5
#                      Orion          5
#                      Paul           5
#                      Payton         5
#                      Quentin        5
#                      Rayden         5
#                      Raymond        5
#                      Russell        5
#                      Sean           5
#                      Teegan         5
#                      Trace          5
#                      Troy           5
#                      Tyce           5
#                      Zayne          5
#
# [1069222 rows x 1 columns]

# %%
final = final_df.loc[("10s", "AK", ["F","M"]), :].nlargest(10,"count")
final
# Out:
#                                count
# decades state gender name
# 10s     AK    M      John        194
#               F      Mary        189
#               M      William     130
#                      James       103
#               F      Margaret     92
#               M      George       92
#               F      Helen        89
#               M      Robert       83
#                      Charles      61
#               F      Annie        53

# %%
finaldf = final.reset_index()
finaldf
# Out:
#   decades state gender      name  count
# 0     10s    AK      M      John    194
# 1     10s    AK      F      Mary    189
# 2     10s    AK      M   William    130
# 3     10s    AK      M     James    103
# 4     10s    AK      F  Margaret     92
# 5     10s    AK      M    George     92
# 6     10s    AK      F     Helen     89
# 7     10s    AK      M    Robert     83
# 8     10s    AK      M   Charles     61
# 9     10s    AK      F     Annie     53

# %%
clean_df = final_df.reset_index()
clean_df.head(4)
# Out:
#   decades state gender      name  count
# 0     10s    AK      F      Mary    189
# 1     10s    AK      F  Margaret     92
# 2     10s    AK      F     Helen     89
# 3     10s    AK      F     Annie     53

# %%
i = 0
for index, row in clean_df.iterrows():
    i+=1
print(i)
# Out:
# 1069222

# %%
import folium

# %%
df = pd.read_excel('Latitude Longitude for each state.xlsx')
df.head()

# %%
merge_table = pd.merge(df, clean_df, on="state")
merge_table

# %%
revised_merge_table = merge_table.drop(('State (full name)'),axis=1)
revised_merge_table.head()

# %%
df = revised_merge_table.groupby(["state", "name", "gender"])
df.head()

# %%
revised_merge_table.to_csv("name_and_coordinates.csv",index=False)

# %%
m = folium.Map(location=[40, -102], tiles='https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', attr='&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors', zoom_start="3.0")
