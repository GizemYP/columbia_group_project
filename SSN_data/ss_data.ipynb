# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Load 2018 national datafile.  files are available on state basis
y2018_data =pd.read_csv("data/yob2018.csv", header=None,names=['Name', 'Sex','Number'])
y2018_data.head()
# Out:
#        Name Sex  Number
# 0      Emma   F   18688
# 1    Olivia   F   17921
# 2       Ava   F   14924
# 3  Isabella   F   14464
# 4    Sophia   F   13928

# %%
#load by State from excel with multiple tabs
#reads first tab only
byState=pd.read_excel("data/byState.xlsx", header=None, names=['State', 'Sex', 'year', 'Name', 'Number'])
byState.head()
# Out:
#   State Sex  year      Name  Number
# 0    AK   F  1910      Mary      14
# 1    AK   F  1910     Annie      12
# 2    AK   F  1910      Anna      10
# 3    AK   F  1910  Margaret       8
# 4    AK   F  1910     Helen       7

# %%
#reads all sheets, but into a directory
xls=pd.ExcelFile('data/byState.xlsx')
xls.sheet_names
# Out:
# ['AK', 'AL', 'AR']

# %%
by_State=pd.read_excel('data/byState.xlsx', sheet_name=None, header=None, names=['State', 'Sex', 'year', 'Name', 'Number'])
by_State #_df=pd.DataFrame(by_State, index="State")
# Out:
# OrderedDict([('AK',       State Sex  year       Name  Number
#               0        AK   F  1910       Mary      14
#               1        AK   F  1910      Annie      12
#               2        AK   F  1910       Anna      10
#               3        AK   F  1910   Margaret       8
#               4        AK   F  1910      Helen       7
#               5        AK   F  1910      Elsie       6
#               6        AK   F  1910       Lucy       6
#               7        AK   F  1910    Dorothy       5
#               8        AK   F  1911       Mary      12
#               9        AK   F  1911   Margaret       7
#               10       AK   F  1911       Ruth       7
#               11       AK   F  1911      Annie       6
#               12       AK   F  1911  Elizabeth       6
#               13       AK   F  1911      Helen       6
#               14       AK   F  1912       Mary       9
#               15       AK   F  1912      Elsie       8
# ...

# %%
# I will look into how to convert dictionary into df tomorrow

# %%
c=d6tstack.convert_xls.XLStoCSVMultiSheet('data/byState.xlsx', output_dir='data/output', logger-PrintLogger())
c.convert_all()
# Out:
#   File "<ipython-input-10-60dfb316431b>", line 1
#     c=d6tstack.convert_xls.XLStoCSVMultiSheet('data/byState.xlsx', output_dir='data/output', logger-PrintLogger())
#                                                                                             ^
# SyntaxError: positional argument follows keyword argument
